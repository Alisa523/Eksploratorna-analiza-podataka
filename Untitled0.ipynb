# %% [markdown]
# <a href="https://colab.research.google.com/github/Alisa523/Eksploratorna-analiza-podataka/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt




data = pd.read_csv("diabetes_risk_prediction_dataset.csv")

data=data.replace('No',0)
data=data.replace('Yes',1)

data=data.replace('Negative',0)
data=data.replace('Positive',1)

data=data.replace('Male',0)
data=data.replace('Female',1)

sns.scatterplot(data, x=data['Age'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Gender'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Polyuria'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Polydipsia'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['sudden weight loss'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['weakness'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Polyphagia'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Genital thrush'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['visual blurring'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Itching'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Irritability'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['delayed healing'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['partial paresis'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['muscle stiffness'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Alopecia'], y=data['class'])
plt.show

sns.scatterplot(data, x=data['Obesity'], y=data['class'])
plt.show



cor=data.corr()
sns.heatmap(cor)
cor.iloc[-1]
print(cor.iloc[-1])
# Out:
# Age                   0.108679
# Gender                0.449233
# Polyuria              0.665922
# Polydipsia            0.648734
# sudden weight loss    0.436568
# weakness              0.243275
# Polyphagia            0.342504
# Genital thrush        0.110288
# visual blurring       0.251300
# Itching              -0.013384
# Irritability          0.299467
# delayed healing       0.046980
# partial paresis       0.432288
# muscle stiffness      0.122474
# Alopecia             -0.267512
# Obesity               0.072173
# class                 1.000000
# Name: class, dtype: float64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sigmoid = lambda x, b0, b1 : 1 / (1 + np.e ** -(b0 + b1*x))
x = np.linspace(-10,10)
y = sigmoid(x, 0, 1)
sns.lineplot(x=x, y=y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=0.2)
print(len(data))
print(len(train))
print(len(test))
# Out:
# 520
# 416
# 104

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(train[['Polyuria']], train['class'])
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

y_pred = clf.predict(test[['Polyuria']])
y_true = test['class']

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.97      0.78        33
#            1       0.98      0.76      0.86        71
#
#     accuracy                           0.83       104
#    macro avg       0.82      0.87      0.82       104
# weighted avg       0.88      0.83      0.83       104
